# %%
import cv2                                  ####Image manipulation
img = cv2.imread('01.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from gtts import gTTS                        ####Text to Speech
import IPython
sentence = "Akshat Choop chap kaam karo. Please Akshat choop chap kam karo."#Your Sentence Here
aud = gTTS(sentence,lang = 'hi',slow = False)#lang stands for language
aud.save('audio.wav')#extension are editable
IPython.display.Audio('audio.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pytesseract                            ####OCR using pyTesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image, ImageEnhance, ImageFilter
#from IPython.display import Image
#Image(filename='temp.png')
#im = Image.open("temp.png")

##Filtering
#im = im.filter(ImageFilter.MedianFilter())
#enhancer = ImageEnhance.Contrast(im)
#im = enhancer.enhance(2)
#im = im.convert('1')
#im.save('temp2.jpg')

##Filtering ends
text = pytesseract.image_to_string(Image.open('tess.png'))
print(text)
# Out:
# phenomena, To be sure, we often transfer results of other branches of science.
# For instance, we realize that the propagation of neural impulses is an
# electric phenomenon and make use, of course, of our knowledge of electricity.
# But it is a common feature of all branches of physical science that is eluci-
# dated in thermodynamics. Which are the concepts and terms that are common to
# all branches and therefore should not be derived from any single one?
#
# ‘The conmon feature is the state of equilibrium. The world as a whole
# and many of its parts are unquestionably very far from equilibriun, Yet there
# are many aspects in which parts of nature can properly be described as being
# in equilibrium. Thus the idea of equilibrium appears in many branches of
# science. The state of equilibrimm therefore must be described in en entirely
# general way. This is the topic of classical thermodynamics. The base of
# ...

# %%
import speech_recognition as sr     # import the library
 
r = sr.Recognizer()                 # initialize recognizer
with sr.Microphone() as source:     # mention source it will be either Microphone or audio files.
    print("Speak Anything :")
    audio = r.listen(source)        # listen to the source
    try:
        text = r.recognize_google(audio)    # use recognizer to convert our audio into text part.
        print("You said : {}".format(text))
    except:
        print("Sorry could not recognize your voice")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c2d2be9ad1e1> in <module>
#       2
#       3 r = sr.Recognizer()                 # initialize recognizer
# ----> 4 with sr.Microphone() as source:     # mention source it will be either Microphone or audio files.
#       5     print("Speak Anything :")
#       6     audio = r.listen(source)        # listen to the source
#
# ...

# %%
from os import path
AUDIO_FILE = 'audio.wav'
#AUDIO_FILE = path.join(path.dirname(path.realpath()), "audio.wav")
with sr.AudioFile(AUDIO_FILE) as source:

    audio = r.record(source)  # read the entire audio file
    try:
        text = r.recognize_google(audio)    # use recognizer to convert our audio into text part.
        print("You said : {}".format(text))
    except:
        print("Sorry could not recognize your voice")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py in __enter__(self)
#     202             # attempt to read the file as WAV
# --> 203             self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     204             self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#
# C:\ProgramData\Anaconda3\lib\wave.py in open(f, mode)
#     509     if mode in ('r', 'rb'):
# --> 510         return Wave_read(f)
#     511     elif mode in ('w', 'wb'):
#
# C:\ProgramData\Anaconda3\lib\wave.py in __init__(self, f)
#     163         try:
# --> 164             self.initfp(f)
#     165         except:
#
# C:\ProgramData\Anaconda3\lib\wave.py in initfp(self, file)
# ...
